# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
driver = webdriver.Chrome(r'C:\Users\DELL\Desktop\WEB SCRAPING\chromedriver.exe')
driver.get('https://www.thisiswhyimbroke.com/new/')
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_13216/2742691935.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\DELL\Desktop\WEB SCRAPING\chromedriver.exe')

# %%
last_height = driver.execute_script('return document.body.scrollHeight')

# %%
while True:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(4)
    new_height = driver.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        break
    last_height = new_height

soup = BeautifulSoup(driver.page_source, 'lxml')
product_card = soup.find_all('div', {"class":'ng-scope',"ng-if":"::post.type == 'post'"})
df=pd.DataFrame({'Product_name':[''], 'Product_link':[''], 'Product_price':[''], 'Product_description':[''], 'Product_image':[''], 'Product_sales':['']})
for product in product_card:
    try:
        product_name = product.find('a', class_='ng-binding ng-scope').text
        product_link = product.find('a', class_='ng-binding ng-scope').get('href')
        product_price = product.find('div', class_='price ng-binding').text
        product_description = product.find('p', class_='ng-binding').text
        product_image = product.find('img', class_='img-fixed lazy-image--handled').get('src')
        product_sales = product.find('a', class_='saved-count ng-binding').text
        df= df.append({'Product_name':product_name, 'Product_link':product_link, 'Product_price':product_price, 'Product_description':product_description,'Product_image':product_image,'Product_sales':Product_sales }, ignore_index=True)
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13216/593021277.py in <module>
#       1 while True:
#       2     driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
# ----> 3     time.sleep(4)
#       4     new_height = driver.execute_script('return document.body.scrollHeight')
#       5     if new_height == last_height:
#
# KeyboardInterrupt:

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
product_card = soup.find_all('div', {"class":'ng-scope',"ng-if":"::post.type == 'post'"})
df=pd.DataFrame({'Product_name':[''], 'Product_link':[''], 'Product_price':[''], 'Product_description':[''], 'Product_image':[''], 'Product_sales':['']})
for product in product_card:
    try:
        product_name = product.find('a', class_='ng-binding ng-scope').text
        product_link = product.find('a', class_='ng-binding ng-scope').get('href')
        product_price = product.find('div', class_='price ng-binding').text
        product_description = product.find('p', class_='ng-binding').text
        product_image = product.find('img', class_='img-fixed lazy-image--handled').get('src')
        product_sales = product.find('a', class_='saved-count ng-binding').text
        df= df.append({'Product_name':product_name, 'Product_link':product_link, 'Product_price':product_price, 'Product_description':product_description,'Product_image':product_image,'Product_sales':product_sales }, ignore_index=True)
    except:
        pass
    

df
# Out:
#                               Product_name  \
# 0
# 1              How to Smoke Pot (Properly)
# 2                  Woolly Mammoth Meatball
# 3        Elements Range Wood Fired Hot Tub
# 4                  Disney Castle Playhouse
# ...                                    ...
# 1659                OnlyCat Smart Cat Flap
# 1660               Eucalyptus Shower Bunch
# 1661  Battle Approved Stomper Electric ATV
# 1662                     Book In A Bag Kit
# 1663                       Pyramid PC Case
#
#                                          Product_link Product_price  \
# 0
# 1                         /how-to-smoke-pot-properly/        $16.66
# 2                           /woolly-mammoth-meatball/
# 3     /koto-design-elements-range-wood-fired-hot-tub/     $7,712.19
# 4                           /disney-castle-playhouse/   $500,000.00
# ...                                               ...           ...
# 1659                         /onlycat-smart-cat-flap/
# 1660                        /eucalyptus-shower-bunch/        $12.99
# 1661           /battle-approved-stomper-electric-atv/
# 1662                              /book-in-a-bag-kit/        $24.99
# 1663                                /pyramid-pc-case/       $389.99
#
#                                     Product_description  \
# 0
# 1     Get on the fast track to becoming a cannabis c...
# 2     Behold the world’s first woolly mammoth meatba...
# 3     Make cold days something to look forward to wi...
# 4     This Disney castle playhouse will make your li...
# ...                                                 ...
# 1659  The OnlyCat smart cat flap will keep unwanted ...
# 1660  Hang up this eucalyptus bunch and transform yo...
# 1661  Conquer any terrain that comes your way in an ...
# 1662  Book in a bag kit will aid the writer in your ...
# 1663  Set your rig apart from the rest with this bol...
#
#                                           Product_image Product_sales
# 0
# 1     https://cdn.thisiswhyimbroke.com/thumb/how-to-...   313 saves\n
# 2     https://cdn.thisiswhyimbroke.com/thumb/woolly-...    25 saves\n
# 3     https://cdn.thisiswhyimbroke.com/thumb/koto-de...    25 saves\n
# 4     https://cdn.thisiswhyimbroke.com/thumb/disney-...    84 saves\n
# ...                                                 ...           ...
# 1659  https://cdn.thisiswhyimbroke.com/thumb/onlycat...   154 saves\n
# 1660  https://cdn.thisiswhyimbroke.com/thumb/eucalyp...    62 saves\n
# 1661  https://cdn.thisiswhyimbroke.com/thumb/battle-...   150 saves\n
# 1662  https://cdn.thisiswhyimbroke.com/thumb/book-in...   224 saves\n
# 1663  https://cdn.thisiswhyimbroke.com/thumb/pyramid...   272 saves\n
#
# [1664 rows x 6 columns]

# %%
df.to_excel(r'C:\Users\DELL\Desktop\thisiswhyimbroke_new.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13216/4128216356.py in <module>
# ----> 1 df.to_excel(r'C:\Users\DELL\Desktop\thisiswhyimbroke_new.xlsx')
#
# AttributeError: 'NoneType' object has no attribute 'to_excel'

# %%
df = df.dropna()
df
# Out:
#                               Product_name  \
# 0
# 1              How to Smoke Pot (Properly)
# 2                  Woolly Mammoth Meatball
# 3        Elements Range Wood Fired Hot Tub
# 4                  Disney Castle Playhouse
# ...                                    ...
# 1659                OnlyCat Smart Cat Flap
# 1660               Eucalyptus Shower Bunch
# 1661  Battle Approved Stomper Electric ATV
# 1662                     Book In A Bag Kit
# 1663                       Pyramid PC Case
#
#                                          Product_link Product_price  \
# 0
# 1                         /how-to-smoke-pot-properly/        $16.66
# 2                           /woolly-mammoth-meatball/
# 3     /koto-design-elements-range-wood-fired-hot-tub/     $7,712.19
# 4                           /disney-castle-playhouse/   $500,000.00
# ...                                               ...           ...
# 1659                         /onlycat-smart-cat-flap/
# 1660                        /eucalyptus-shower-bunch/        $12.99
# 1661           /battle-approved-stomper-electric-atv/
# 1662                              /book-in-a-bag-kit/        $24.99
# 1663                                /pyramid-pc-case/       $389.99
#
#                                     Product_description  \
# 0
# 1     Get on the fast track to becoming a cannabis c...
# 2     Behold the world’s first woolly mammoth meatba...
# 3     Make cold days something to look forward to wi...
# 4     This Disney castle playhouse will make your li...
# ...                                                 ...
# 1659  The OnlyCat smart cat flap will keep unwanted ...
# 1660  Hang up this eucalyptus bunch and transform yo...
# 1661  Conquer any terrain that comes your way in an ...
# 1662  Book in a bag kit will aid the writer in your ...
# 1663  Set your rig apart from the rest with this bol...
#
#                                           Product_image Product_sales
# 0
# 1     https://cdn.thisiswhyimbroke.com/thumb/how-to-...   313 saves\n
# 2     https://cdn.thisiswhyimbroke.com/thumb/woolly-...    25 saves\n
# 3     https://cdn.thisiswhyimbroke.com/thumb/koto-de...    25 saves\n
# 4     https://cdn.thisiswhyimbroke.com/thumb/disney-...    84 saves\n
# ...                                                 ...           ...
# 1659  https://cdn.thisiswhyimbroke.com/thumb/onlycat...   154 saves\n
# 1660  https://cdn.thisiswhyimbroke.com/thumb/eucalyp...    62 saves\n
# 1661  https://cdn.thisiswhyimbroke.com/thumb/battle-...   150 saves\n
# 1662  https://cdn.thisiswhyimbroke.com/thumb/book-in...   224 saves\n
# 1663  https://cdn.thisiswhyimbroke.com/thumb/pyramid...   272 saves\n
#
# [1664 rows x 6 columns]

# %%
#df['Product_price']=df['Product_price'].apply(lambda x: x.strip('$'))
#df['Product_price'] =df['Product_price'].apply(lambda x: float(x.replace('.',''))
df['Product_price']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13216/2349583385.py in <module>
#       1 #df['Product_price']=df['Product_price'].apply(lambda x: x.strip('$'))
#       2 #df['Product_price'] =df['Product_price'].apply(lambda x: float(x.replace('.',''))
# ----> 3 df['Product_price']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
product_card = soup.find_all('div', {"class":'ng-scope',"ng-if":"::post.type == 'post'"})
#df=pd.DataFrame({'Product_name':[''], 'Product_link':[''], 'Product_price':[''], 'Product_description':['']})
df=pd.DataFrame({'Product_name':[''], 'Product_link':[''], 'Product_price':[''], 'Product_description':[''], 'Product_image':[''], 'Product_sales':['']})
for product in product_card:
    try:
        product_name = product.find('a', class_='ng-binding ng-scope').text
        product_link = product.find('a', class_='ng-binding ng-scope').get('href')
        product_price = product.find('div', class_='price ng-binding').text
        product_description = product.find('p', class_='ng-binding').text
        product_image = product.find('img', class_='img-fixed lazy-image--handled').get('src')
        product_sales = product.find('a', class_='saved-count ng-binding').text
        df= df.append({'Product_name':product_name, 'Product_link':product_link, 'Product_price':product_price, 'Product_description':product_description,'Product_image':product_image,'Product_sales':Product_sales},ignore_index=True)
    except:
        pass
df
# Out:
#   Product_name Product_link Product_price Product_description Product_image  \
# 0
#
#   Product_sales
# 0

# %%
df.to_excel(r'C:\Users\DELL\Desktop\thisiswhyimbroke.xlsx')

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
product_card = soup.find_all('div', {"class":'ng-scope',"ng-if":"::post.type == 'post'"})
soup.find('img', class_='img-fixed lazy-image--handled').get('src')
# Out:
# 'https://cdn.thisiswhyimbroke.com/thumb/how-to-smoke-pot-properly_400x333.jpg'

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\DELL\Desktop\thisiswhyimbroke_new.xlsx')
df
# Out:
#       Unnamed: 0                          Product_name  \
# 0              0                                   NaN
# 1              1           How to Smoke Pot (Properly)
# 2              2               Woolly Mammoth Meatball
# 3              3     Elements Range Wood Fired Hot Tub
# 4              4               Disney Castle Playhouse
# ...          ...                                   ...
# 1659        1659                OnlyCat Smart Cat Flap
# 1660        1660               Eucalyptus Shower Bunch
# 1661        1661  Battle Approved Stomper Electric ATV
# 1662        1662                     Book In A Bag Kit
# 1663        1663                       Pyramid PC Case
#
#                                          Product_link Product_price  \
# 0                                                 NaN           NaN
# 1                         /how-to-smoke-pot-properly/        $16.66
# 2                           /woolly-mammoth-meatball/
# 3     /koto-design-elements-range-wood-fired-hot-tub/     $7,712.19
# 4                           /disney-castle-playhouse/   $500,000.00
# ...                                               ...           ...
# 1659                         /onlycat-smart-cat-flap/
# 1660                        /eucalyptus-shower-bunch/        $12.99
# 1661           /battle-approved-stomper-electric-atv/
# 1662                              /book-in-a-bag-kit/        $24.99
# 1663                                /pyramid-pc-case/       $389.99
#
#                                     Product_description  \
# 0                                                   NaN
# 1     Get on the fast track to becoming a cannabis c...
# 2     Behold the world’s first woolly mammoth meatba...
# 3     Make cold days something to look forward to wi...
# 4     This Disney castle playhouse will make your li...
# ...                                                 ...
# 1659  The OnlyCat smart cat flap will keep unwanted ...
# 1660  Hang up this eucalyptus bunch and transform yo...
# 1661  Conquer any terrain that comes your way in an ...
# 1662  Book in a bag kit will aid the writer in your ...
# 1663  Set your rig apart from the rest with this bol...
#
#                                           Product_image Product_sales
# 0                                                   NaN           NaN
# 1     https://cdn.thisiswhyimbroke.com/thumb/how-to-...   313 saves\n
# 2     https://cdn.thisiswhyimbroke.com/thumb/woolly-...    25 saves\n
# 3     https://cdn.thisiswhyimbroke.com/thumb/koto-de...    25 saves\n
# 4     https://cdn.thisiswhyimbroke.com/thumb/disney-...    84 saves\n
# ...                                                 ...           ...
# 1659  https://cdn.thisiswhyimbroke.com/thumb/onlycat...   154 saves\n
# 1660  https://cdn.thisiswhyimbroke.com/thumb/eucalyp...    62 saves\n
# 1661  https://cdn.thisiswhyimbroke.com/thumb/battle-...   150 saves\n
# 1662  https://cdn.thisiswhyimbroke.com/thumb/book-in...   224 saves\n
# 1663  https://cdn.thisiswhyimbroke.com/thumb/pyramid...   272 saves\n
#
# [1664 rows x 7 columns]

# %%
type(df['Product_price'][1])
# Out:
# str

# %%
df['Product_price'] = df['Product_price'].astype(str).apply(lambda x: x.strip('$'))
# Out:
# 0              nan
# 1            16.66
# 2
# 3         7,712.19
# 4       500,000.00
#            ...
# 1659
# 1660         12.99
# 1661
# 1662         24.99
# 1663        389.99
# Name: Product_price, Length: 1664, dtype: object

# %%
df['Product_price'] = df['Product_price'].apply(lambda x: x.strip(' \xa0'))

# %%
rows_to_drop = df.loc[df.eq('').any(axis=1)]
df = df.drop(rows_to_drop.index)

# %%
df.to_excel(r'C:\Users\DELL\Desktop\thisiswhyimbroke_new1.xlsx')

# %%
df = pd.read_excel(r'C:\Users\DELL\Desktop\thisiswhyimbroke_new1.xlsx')
df
# Out:
#                             Product_name  \
# 0            How to Smoke Pot (Properly)
# 1      Elements Range Wood Fired Hot Tub
# 2                Disney Castle Playhouse
# 3                    Mini Desktop Cannon
# 4                Anker 737 MagGo Charger
# ...                                  ...
# 1490             The Deck Of Many Things
# 1491  Bandit9 Monaco Electric Sports Car
# 1492             Eucalyptus Shower Bunch
# 1493                   Book In A Bag Kit
# 1494                     Pyramid PC Case
#
#                                          Product_link Product_price  \
# 0                         /how-to-smoke-pot-properly/         16.66
# 1     /koto-design-elements-range-wood-fired-hot-tub/      7,712.19
# 2                           /disney-castle-playhouse/    500,000.00
# 3                               /mini-desktop-cannon/         15.00
# 4                           /anker-737-maggo-charger/        139.99
# ...                                               ...           ...
# 1490                        /the-deck-of-many-things/         15.99
# 1491             /bandit9-monaco-electric-sports-car/    149,911.50
# 1492                        /eucalyptus-shower-bunch/         12.99
# 1493                              /book-in-a-bag-kit/         24.99
# 1494                                /pyramid-pc-case/        389.99
#
#                                     Product_description  \
# 0     Get on the fast track to becoming a cannabis c...
# 1     Make cold days something to look forward to wi...
# 2     This Disney castle playhouse will make your li...
# 3     Make your dream of owning a functioning cannon...
# 4     Do away with cables and charge your device the...
# ...                                                 ...
# 1490  Help your favorite DM torture his players prop...
# 1491  Rediscover the joy of driving behind the wheel...
# 1492  Hang up this eucalyptus bunch and transform yo...
# 1493  Book in a bag kit will aid the writer in your ...
# 1494  Set your rig apart from the rest with this bol...
#
#                                           Product_image Product_sales
# 0     https://cdn.thisiswhyimbroke.com/thumb/how-to-...   313 saves\n
# 1     https://cdn.thisiswhyimbroke.com/thumb/koto-de...    25 saves\n
# 2     https://cdn.thisiswhyimbroke.com/thumb/disney-...    84 saves\n
# 3     https://cdn.thisiswhyimbroke.com/thumb/mini-de...   234 saves\n
# 4     https://cdn.thisiswhyimbroke.com/thumb/anker-7...    18 saves\n
# ...                                                 ...           ...
# 1490  https://cdn.thisiswhyimbroke.com/thumb/the-dec...    84 saves\n
# 1491  https://cdn.thisiswhyimbroke.com/thumb/bandit9...   170 saves\n
# 1492  https://cdn.thisiswhyimbroke.com/thumb/eucalyp...    62 saves\n
# 1493  https://cdn.thisiswhyimbroke.com/thumb/book-in...   224 saves\n
# 1494  https://cdn.thisiswhyimbroke.com/thumb/pyramid...   272 saves\n
#
# [1495 rows x 6 columns]

# %%
type(df['Product_description'][1000])
# Out:
# str

# %%
df['Product_description'] = df['Product_description'].apply(lambda x: x[:80])
df['Product_description']
# Out:
# 0       Get on the fast track to becoming a cannabis c...
# 1       Make cold days something to look forward to wi...
# 2       This Disney castle playhouse will make your li...
# 3       Make your dream of owning a functioning cannon...
# 4       Do away with cables and charge your device the...
#                               ...
# 1490    Help your favorite DM torture his players prop...
# 1491    Rediscover the joy of driving behind the wheel...
# 1492    Hang up this eucalyptus bunch and transform yo...
# 1493    Book in a bag kit will aid the writer in your ...
# 1494    Set your rig apart from the rest with this bol...
# Name: Product_description, Length: 1495, dtype: object
